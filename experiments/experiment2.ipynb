# %%
import json
import matplotlib.pyplot as plt


arr = [(1,4), (2,6), (3,1), (4,9), (5,3), (6,9), (7,8)]


x = [1,2,3,4,5,6,7]
y = [3,7,8,5,6,9,3]

plt.plot(x,y)


with open("storetest.json", "w") as f:
    json.dump([x,y], f)

with open("storetest.json", "r") as f:
    p = json.load(f)
p
# Out:
# [[1, 2, 3, 4, 5, 6, 7], [3, 7, 8, 5, 6, 9, 3]]
