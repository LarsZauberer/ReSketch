# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("full_numpy_bitmap_flower.npy", encoding="latin1", allow_pickle=True)

# %%
data.shape
# Out:
# (144818, 784)

# %%
# data[0].reshape(28, 28)

# %%
for i in range(10):
    plt.imshow(data[i].reshape(28, 28), cmap="gray")
    plt.show()
